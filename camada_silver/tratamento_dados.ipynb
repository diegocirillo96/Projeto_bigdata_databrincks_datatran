# %%
df_bronze = spark.table("projeto_profissional_bigdata.datatran_2018.bronze_datatran2018")

# %%
df_bronze.printSchema()

# %%
df_bronze.show(10)

# %%
df_bronze.select(
    "id",
    "data_inversa",
    "uf",
    "km",
    "br",
    "municipio",
    "causa_acidente").show(5,truncate = False)
